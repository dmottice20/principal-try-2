# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read in the data.

# %%
# Read in data, check shape, and calculate descriptive statistics.
fred = pd.read_csv('data/newFred.csv')
print('Size of FRED data:', fred.shape)
descriptor = fred.describe()
descriptor.iloc[:, :10]
# Out:
# Size of FRED data: (1231, 59)
#            AWHMAN     AWOTMAN     BUSLOANS         CE16OV  CES0600000007  \
# count  991.000000  787.000000   895.000000     883.000000     895.000000
# mean    40.787588    3.675222   636.723324  105260.275198      40.222905
# std      1.195234    0.768915   679.350352   32506.638316       0.658892
# min     37.000000    1.800000    11.289400   57172.000000      37.200000
# 25%     40.200000    3.100000    65.933750   72642.500000      39.800000
# 50%     40.700000    3.700000   437.837400  105638.000000      40.200000
# 75%     41.300000    4.300000   986.872800  137513.000000      40.700000
# max     45.700000    5.300000  3039.906200  158735.000000      41.700000
#
#        CES1021000001        CLF16OV      CMRMTSPL      CUMFNS       DMANEMP
# count      763.00000     883.000000  6.540000e+02  883.000000    991.000000
# mean       678.27287  111866.714609  9.068975e+05   79.846052   9432.624622
# ...

# %%
descriptor.iloc[:, 10:20]
# Out:
#        DPCERA3M086SBEA    DTCOLNVHFNM       DTCTHFNM        HOUST     HOUSTMW  \
# count       751.000000     942.000000     942.000000   751.000000  751.000000
# mean         60.612336   96002.951815  258662.855318  1430.295606  278.555260
# std          31.638404  114858.538177  312944.294453   388.483661   99.179699
# min          17.272000     158.000000     728.000000   478.000000   59.000000
# 25%          32.352000    7697.750000   16703.250000  1193.000000  205.500000
# 50%          54.252000   40174.500000   73400.440000  1455.000000  286.000000
# 75%          92.401000  190872.945000  556937.447500  1650.000000  347.000000
# max         123.891000  367397.570000  896985.060000  2494.000000  590.000000
#
#           HOUSTNE       HOUSTS      HOUSTW       INDPRO   IPB51222S
# count  751.000000   751.000000  751.000000  1231.000000  811.000000
# mean   172.316911   634.182423  345.249001    44.469206   68.250589
# ...

# %%
descriptor.iloc[:, 20:30]
# Out:
#           IPBUSEQ     IPCONGD    IPDCONGD      IPDMAT     IPFINAL     IPFPNSS  \
# count  895.000000  991.000000  895.000000  895.000000  991.000000  991.000000
# mean    44.467773   63.943163   56.010472   44.058445   56.241859   57.338441
# std     34.623378   31.816890   30.914265   32.902544   32.911313   32.974542
# min      4.714600   11.770800   11.925800    5.611300    7.309100    7.695600
# 25%     12.995050   32.533700   30.626050   18.878150   23.140800   24.235400
# 50%     32.560400   65.432300   49.317700   29.031200   53.435000   54.685900
# 75%     80.404050   97.955400   86.590150   77.737350   94.592150   96.040650
# max    105.203700  111.295700  107.784700  105.024600  108.580800  110.068300
#
#           IPFUELS    IPMANSICS       IPMAT    IPNCONGD
# count  811.000000  1231.000000  991.000000  895.000000
# mean    64.617655    44.402628   49.900746   74.819860
# std     19.667493    34.854826   30.418317   27.801291
# ...

# %%
descriptor.iloc[:, 30:40]
# Out:
#            IPNMAT          M1SL       M2REAL          M2SL        MANEMP  \
# count  811.000000    751.000000   751.000000    751.000000    991.000000
# mean    81.766939   1384.010652  2760.695606   4568.435553  15556.027245
# std     27.177788   2555.782332  1399.573788   4560.374994   2336.479298
# min     22.933200    138.900000   987.900000    286.600000   9077.000000
# 25%     62.172700    270.550000  1835.800000    886.000000  14028.000000
# 50%     92.551200    804.200000  2391.400000   3200.600000  15832.000000
# 75%    101.763000   1371.400000  3365.350000   6666.750000  17503.000000
# max    115.989300  19402.000000  7586.200000  20534.600000  19553.000000
#
#               PAYEMS       REALLN           RPI         SRVPRD     UEMP15OV
# count     991.000000   895.000000    751.000000     991.000000   883.000000
# mean    90077.711403  1195.458440   8561.801019   69319.629667  2222.378256
# std     36839.474846  1505.657411   4397.444144   35525.905110  1844.660486
# ...

# %%
descriptor.iloc[:, 40:50]
# Out:
#          UEMP15T26     UEMP27OV     UEMP5TO14       UEMPLT5    UEMPMEAN  \
# count   883.000000   883.000000    883.000000    883.000000  883.000000
# mean    939.089468  1283.279728   1938.524349   2446.391846   16.225368
# std     615.647308  1326.265147    963.451639    813.173313    7.222971
# min      96.000000    48.000000    394.000000    973.000000    6.100000
# 25%     519.000000   430.500000   1226.500000   1738.000000   11.700000
# 50%     879.000000   928.000000   2011.000000   2546.000000   14.400000
# 75%    1203.000000  1576.000000   2453.500000   2935.500000   18.050000
# max    6536.000000  6800.000000  14804.000000  14282.000000   40.700000
#
#            UNRATE       USCONS       USFIRE        USGOOD        USGOVT
# count  883.000000   991.000000   991.000000    991.000000    991.000000
# mean     5.768177  4412.204844  4982.976791  20758.081736  14669.237134
# std      1.700392  1800.390828  2548.458580   2791.392129   6185.450711
# ...

# %%
descriptor.iloc[:, 50:]
# Out:
#             USTRADE     USWTRADE       W875RX1  WPSFD49207  WPSFD49502  \
# count    991.000000   991.000000    751.000000  892.000000  892.000000
# mean    9963.310494  4077.079112   7332.305859   99.608520  101.865022
# std     4415.117639  1485.602903   3504.633702   60.948206   64.190819
# min     3107.800000  1463.400000   2293.200000   26.000000   28.300000
# 25%     5486.700000  2642.450000   4277.200000   34.475000   34.650000
# 50%    10238.500000  4490.400000   6761.400000  102.850000  101.550000
# 75%    14643.650000  5561.950000  10480.350000  141.925000  143.275000
# max    15920.000000  5969.700000  14225.600000  221.000000  235.400000
#
#           WPSID61     WPSID62     ISRATIO
# count  892.000000  892.000000  354.000000
# mean    96.872982   99.572646    1.372514
# std     61.260277   67.898572    0.081662
# min     23.000000   29.000000    1.240000
# 25%     31.375000   33.500000    1.292500
# 50%    100.250000   95.900000    1.380000
# ...

# %% [markdown]
# It is obvious to note that there are missing values present in the data. This is mostly due to not having data reach back to the year 1919 for most features present in the FRED data pull, as demonstrated below.

# %%
fred.head()
# Out:
#          DATE  AWHMAN  AWOTMAN  BUSLOANS  CE16OV  CES0600000007  \
# 0  1919-01-01     NaN      NaN       NaN     NaN            NaN
# 1  1919-02-01     NaN      NaN       NaN     NaN            NaN
# 2  1919-03-01     NaN      NaN       NaN     NaN            NaN
# 3  1919-04-01     NaN      NaN       NaN     NaN            NaN
# 4  1919-05-01     NaN      NaN       NaN     NaN            NaN
#
#    CES1021000001  CLF16OV  CMRMTSPL  CUMFNS  ...  USGOOD  USGOVT  USTRADE  \
# 0            NaN      NaN       NaN     NaN  ...     NaN     NaN      NaN
# 1            NaN      NaN       NaN     NaN  ...     NaN     NaN      NaN
# 2            NaN      NaN       NaN     NaN  ...     NaN     NaN      NaN
# 3            NaN      NaN       NaN     NaN  ...     NaN     NaN      NaN
# 4            NaN      NaN       NaN     NaN  ...     NaN     NaN      NaN
#
#    USWTRADE  W875RX1  WPSFD49207  WPSFD49502  WPSID61  WPSID62  ISRATIO
# ...

# %%
type(fred.DATE.values[0])
# Out:
# str

# %%
fred.columns
# Out:
# Index(['DATE', 'AWHMAN', 'AWOTMAN', 'BUSLOANS', 'CE16OV', 'CES0600000007',
#        'CES1021000001', 'CLF16OV', 'CMRMTSPL', 'CUMFNS', 'DMANEMP',
#        'DPCERA3M086SBEA', 'DTCOLNVHFNM', 'DTCTHFNM', 'HOUST', 'HOUSTMW',
#        'HOUSTNE', 'HOUSTS', 'HOUSTW', 'INDPRO', 'IPB51222S', 'IPBUSEQ',
#        'IPCONGD', 'IPDCONGD', 'IPDMAT', 'IPFINAL', 'IPFPNSS', 'IPFUELS',
#        'IPMANSICS', 'IPMAT', 'IPNCONGD', 'IPNMAT', 'M1SL', 'M2REAL', 'M2SL',
#        'MANEMP', 'PAYEMS', 'REALLN', 'RPI', 'SRVPRD', 'UEMP15OV', 'UEMP15T26',
#        'UEMP27OV', 'UEMP5TO14', 'UEMPLT5', 'UEMPMEAN', 'UNRATE', 'USCONS',
#        'USFIRE', 'USGOOD', 'USGOVT', 'USTRADE', 'USWTRADE', 'W875RX1',
#        'WPSFD49207', 'WPSFD49502', 'WPSID61', 'WPSID62', 'ISRATIO'],
#       dtype='object')

# %%
fred['AWHMAN'].first_valid_index()
# Out:
# 240

# %%
fred['AWHMAN'].values[240]
# Out:
# 37.1

# %%
fred.iloc[:10, :]
# Out:
#          DATE  AWHMAN  AWOTMAN  BUSLOANS  CE16OV  CES0600000007  \
# 0  1919-01-01     NaN      NaN       NaN     NaN            NaN
# 1  1919-02-01     NaN      NaN       NaN     NaN            NaN
# 2  1919-03-01     NaN      NaN       NaN     NaN            NaN
# 3  1919-04-01     NaN      NaN       NaN     NaN            NaN
# 4  1919-05-01     NaN      NaN       NaN     NaN            NaN
# 5  1919-06-01     NaN      NaN       NaN     NaN            NaN
# 6  1919-07-01     NaN      NaN       NaN     NaN            NaN
# 7  1919-08-01     NaN      NaN       NaN     NaN            NaN
# 8  1919-09-01     NaN      NaN       NaN     NaN            NaN
# 9  1919-10-01     NaN      NaN       NaN     NaN            NaN
#
#    CES1021000001  CLF16OV  CMRMTSPL  CUMFNS  ...  USGOOD  USGOVT  USTRADE  \
# 0            NaN      NaN       NaN     NaN  ...     NaN     NaN      NaN
# 1            NaN      NaN       NaN     NaN  ...     NaN     NaN      NaN
# ...
